# %% [markdown]
# # Day 1 — AI/ML Internship Environment Test
#
# **Intern Name:** Shri Sanjaykumar V
# **Role:** AI/ML Intern
# **Organization:** Linkific
# **Objective:** Verify Python runtime, verify standard library operations, and test core mathematical/data manipulation packages (`numpy`, `pandas`).

# %% [markdown]
# ## 1. System & Python Version Check
# Verify the active Python interpreter, platform, and compiler build.

# %%
import sys
import platform

print(f"Python Version: {sys.version}")
print(f"Platform: {platform.system()} {platform.release()} ({platform.architecture()[0]})")
print(f"Executable: {sys.executable}")

# %% [markdown]
# ## 2. Basic Python Functionality Test
# Test standard data structures, list comprehensions, and arithmetic operations.

# %%
# Basic data structure & logic test
sample_data = [12, 45, 67, 23, 89, 90, 34]
even_squares = [x**2 for x in sample_data if x % 2 == 0]

print(f"Original list: {sample_data}")
print(f"Even numbers squared: {even_squares}")
print(f"Sum: {sum(sample_data)}, Average: {sum(sample_data)/len(sample_data):.2f}")

# %% [markdown]
# ## 3. Core Package Verification (NumPy & Pandas)
# Verify that the core scientific libraries listed in `requirements.txt` can be imported and executed successfully.

# %%
import numpy as np
import pandas as pd

print(f"NumPy Version: {np.__version__}")
print(f"Pandas Version: {pd.__version__}")

# NumPy Array computation test
matrix_a = np.array([[1, 2], [3, 4]])
matrix_b = np.array([[5, 6], [7, 8]])
matrix_product = np.dot(matrix_a, matrix_b)

print("\nMatrix Multiplication Result:")
print(matrix_product)

# Pandas DataFrame creation and summary test
df = pd.DataFrame({
    'Day': [1, 2, 3],
    'Topic': ['Environment & Foundations', 'NumPy & Data Arrays', 'Pandas & DataFrames'],
    'Status': ['Completed', 'Upcoming', 'Upcoming']
})

print("\nPandas DataFrame Verification:")
print(df)

# %% [markdown]
# ## 4. Environment Verification Summary
# Final health status confirmation.

# %%
print("=====================================================")
print("✅ Linkific AI/ML Internship: Day 1 Environment Test PASSED")
print("✅ Python runtime, NumPy, and Pandas are operational.")
print("=====================================================")
